# %%
import pandas as pd
df=pd.read_excel("РБК. Новости. Главное_tg_parsed_no_emoji.xlsx")

# %%
df.head()
# Out:
#                  date                                               text  \
# 0 2025-05-08 07:54:01  Аэропорты Москвы — Шереметьево, Внуково, Домод...
# 1 2025-05-08 07:36:28  Си Цзиньпин заявил, что 80 лет назад «китайски...
# 2 2025-05-08 07:27:13  Путин сказал, что будет рад «вновь посетить др...
# 3 2025-05-08 07:18:55  В Кремле началась встреча Путина и Си Цзиньпин...
# 4 2025-05-08 07:11:21  Истребители Индии и Пакистана сразились в возд...
#
#                            link  picture  video  word_count
# 0  https://t.me/rbc_news/117689        0      0          52
# 1  https://t.me/rbc_news/117688        0      0          72
# 2  https://t.me/rbc_news/117687        0      1          28
# 3  https://t.me/rbc_news/117686        0      1          16
# 4  https://t.me/rbc_news/117685        1      0         152

# %%
average_word_count = df["text"].astype(str).apply(lambda x: len(x.split())).mean()
print(f"Среднее количество слов: {average_word_count:.2f}")
# Out:
# Среднее количество слов: 56.47
